# %% [markdown]
# # YOLO Object Detection
# We will train our own weights for the YOLOv7 model. We have one class we want to detect, snowcones. There's two datasets, one with Lidar images and one with RGB images. We can train our model to either handle both or one model for each of them.

# %% [markdown]
# ## Importing packages

# %%
pip install -r yolov7-main/requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.idi.ntnu.no
# ...
#   Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached protobuf-4.21.2-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
# Using cached protobuf-4.21.2-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt

# %% [markdown]
# ## Training YOLO model

# %%
path_lidar_images_train = "/datsets/tdt4265/ad/open/Poles/lidar/combined_color/train"
path_lidar_label_train  = "/datsets/tdt4265/ad/open/Poles/lidar/labels/train"
path_rgb_images_train   = "/datsets/tdt4265/ad/open/Poles/rgb/images/train"
path_rgb_labels_train   = "/datsets/tdt4265/ad/open/Poles/rgb/labels/train"

# %% [markdown]
# ## Validating the model and weights

# %%
path_lidar_images_valid = "/datsets/tdt4265/ad/open/Poles/lidar/combined_color/valid"
path_lidar_label_valid  = "/datsets/tdt4265/ad/open/Poles/lidar/labels/valid"
path_rgb_images_valid   = "/datsets/tdt4265/ad/open/Poles/rgb/images/valid"
path_rgb_labels_valid   = "/datsets/tdt4265/ad/open/Poles/rgb/labels/valid"

# %% [markdown]
# ## Testing weights on the test-dataset

# %%
path_lidar_images_test = "/datsets/tdt4265/ad/open/Poles/lidar/combined_color/train"
path_rgb_images_test   = "/datsets/tdt4265/ad/open/Poles/rgb/images/test"

# %% [markdown]
# ## Plotting Results
